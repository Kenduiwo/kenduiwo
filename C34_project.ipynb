# %% [markdown]
# <a href="https://colab.research.google.com/github/Kenduiwo/kenduiwo/blob/main/C34_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
kiva = pd.read_csv('kiva_loans.csv')

# %%
kiva.shape
# Out:
# (671205, 20)

# %%
kiva['country'].unique()
# Out:
# array(['Pakistan', 'India', 'Kenya', 'Nicaragua', 'El Salvador',
#        'Tanzania', 'Philippines', 'Peru', 'Senegal', 'Cambodia',
#        'Liberia', 'Vietnam', 'Iraq', 'Honduras', 'Palestine', 'Mongolia',
#        'United States', 'Mali', 'Colombia', 'Tajikistan', 'Guatemala',
#        'Ecuador', 'Bolivia', 'Yemen', 'Ghana', 'Sierra Leone', 'Haiti',
#        'Chile', 'Jordan', 'Uganda', 'Burundi', 'Burkina Faso',
#        'Timor-Leste', 'Indonesia', 'Georgia', 'Ukraine', 'Kosovo',
#        'Albania', 'The Democratic Republic of the Congo', 'Costa Rica',
#        'Somalia', 'Zimbabwe', 'Cameroon', 'Turkey', 'Azerbaijan',
#        'Dominican Republic', 'Brazil', 'Mexico', 'Kyrgyzstan', 'Armenia',
#        'Paraguay', 'Lebanon', 'Samoa', 'Israel', 'Rwanda', 'Zambia',
#        'Nepal', 'Congo', 'Mozambique', 'South Africa', 'Togo', 'Benin',
#        'Belize', 'Suriname', 'Thailand', 'Nigeria', 'Mauritania',
#        'Vanuatu', 'Panama', 'Virgin Islands',
# ...

# %%
brazil=kiva[kiva['country']=='Brazil']

# %%
brazil.shape
# Out:
# (284, 20)

# %%
brazil.head()
# Out:
#            id  funded_amount  loan_amount         activity    sector  \
# 1685   654797         1700.0       1700.0  Cosmetics Sales    Retail
# 16301  669512         1875.0       1875.0         Printing  Services
# 16333  669507         2500.0       2500.0           Retail    Retail
# 22572  675805          225.0        225.0         Services  Services
# 22604  675798          650.0        650.0         Services  Services
#
#                                                      use country_code country  \
# 1685               To buy cream, perfume/cologne, makeup           BR  Brazil
# 16301  To buy material for banner printing, wooden st...           BR  Brazil
# 16333            To buy books, magazines, and newspapers           BR  Brazil
# 22572            to buy games for PlayStation for resale           BR  Brazil
# 22604  To buy raw materials to produce perfumes and s...           BR  Brazil
#
#          region currency  partner_id                posted_time  \
# ...

# %%
loan_themes_by_region=pd.read_csv('loan_themes_by_region.csv')

# %%
loan_themes_by_region.head()
# Out:
#    Partner ID               Field Partner Name                       sector  \
# 0           9  KREDIT Microfinance Institution  General Financial Inclusion
# 1           9  KREDIT Microfinance Institution  General Financial Inclusion
# 2           9  KREDIT Microfinance Institution  General Financial Inclusion
# 3           9  KREDIT Microfinance Institution  General Financial Inclusion
# 4           9  KREDIT Microfinance Institution  General Financial Inclusion
#
#      Loan Theme ID         Loan Theme Type   country forkiva  \
# 0  a1050000000slfi        Higher Education  Cambodia      No
# 1  a10500000068jPe  Vulnerable Populations  Cambodia      No
# 2  a1050000000slfi        Higher Education  Cambodia      No
# 3  a10500000068jPe  Vulnerable Populations  Cambodia      No
# 4  a1050000002X1Uu              Sanitation  Cambodia      No
#
#                   region     geocode_old  ISO  ...  amount  \
# 0       Banteay Meanchey  (13.75, 103.0)  KHM  ...     450
# ...

# %%
mpi=pd.read_csv('kiva_mpi_region_locations.csv')

# %%
mpi.head()
# Out:
#               LocationName  ISO      country      region world_region    MPI  \
# 0  Badakhshan, Afghanistan  AFG  Afghanistan  Badakhshan   South Asia  0.387
# 1     Badghis, Afghanistan  AFG  Afghanistan     Badghis   South Asia  0.466
# 2     Baghlan, Afghanistan  AFG  Afghanistan     Baghlan   South Asia  0.300
# 3       Balkh, Afghanistan  AFG  Afghanistan       Balkh   South Asia  0.301
# 4      Bamyan, Afghanistan  AFG  Afghanistan      Bamyan   South Asia  0.325
#
#                                geo        lat        lon
# 0  (36.7347725, 70.81199529999999)  36.734772  70.811995
# 1         (35.1671339, 63.7695384)  35.167134  63.769538
# 2         (35.8042947, 69.2877535)  35.804295  69.287754
# 3         (36.7550603, 66.8975372)  36.755060  66.897537
# 4         (34.8100067, 67.8212104)  34.810007  67.821210

# %%
loan_themes_id=pd.read_csv('loan_theme_ids.csv')

# %%
loan_themes_id.head()
# Out:
#        id    Loan Theme ID          Loan Theme Type  Partner ID
# 0  638631  a1050000000skGl                  General       151.0
# 1  640322  a1050000000skGl                  General       151.0
# 2  641006  a1050000002X1ij         Higher Education       160.0
# 3  641019  a1050000002X1ij         Higher Education       160.0
# 4  641594  a1050000002VbsW  Subsistence Agriculture       336.0

# %%
themes=loan_themes_by_region[loan_themes_by_region['country']=='Brazil'].reset_index(drop=True)

# %%
themes.tail()
# Out:
#    Partner ID                Field Partner Name                       sector  \
# 3         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 4         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 5         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 6         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 7         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
#
#      Loan Theme ID Loan Theme Type country forkiva        region geocode_old  \
# 3  a1050000000da2V         General  Brazil      No       Diadema         NaN
# 4  a1050000000da2V         General  Brazil      No          Maua         NaN
# 5  a1050000000da2V         General  Brazil      No  Santo AndrÍ©         NaN
# 6  a1050000000da2V         General  Brazil      No    SÍ£o Paulo         NaN
# 7  a1050000000da2V         General  Brazil      No   Vila Luzita         NaN
#
# ...

# %%
kiva.head(2)
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
#
#    region currency  partner_id                posted_time  \
# 0  Lahore      PKR       247.0  2014-01-01 06:12:39+00:00
# 1  Lahore      PKR       247.0  2014-01-01 06:51:08+00:00
#
#               disbursed_time                funded_time  term_in_months  \
# 0  2013-12-17 08:00:00+00:00  2014-01-02 10:06:32+00:00            12.0
# 1  2013-12-17 08:00:00+00:00  2014-01-02 09:17:23+00:00            11.0
#
#    lender_count tags borrower_genders repayment_interval        date
# ...

# %%
kiva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  671205 non-null  int64
#  1   funded_amount       671205 non-null  float64
#  2   loan_amount         671205 non-null  float64
#  3   activity            671205 non-null  object
#  4   sector              671205 non-null  object
#  5   use                 666973 non-null  object
#  6   country_code        671197 non-null  object
#  7   country             671205 non-null  object
#  8   region              614405 non-null  object
#  9   currency            671205 non-null  object
#  10  partner_id          657698 non-null  float64
#  11  posted_time         671205 non-null  object
#  12  disbursed_time      668809 non-null  object
#  13  funded_time         622874 non-null  object
#  14  term_in_months      671205 non-null  float64
# ...

# %%
brazil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 284 entries, 1685 to 665789
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  284 non-null    int64
#  1   funded_amount       284 non-null    float64
#  2   loan_amount         284 non-null    float64
#  3   activity            284 non-null    object
#  4   sector              284 non-null    object
#  5   use                 243 non-null    object
#  6   country_code        284 non-null    object
#  7   country             284 non-null    object
#  8   region              243 non-null    object
#  9   currency            284 non-null    object
#  10  partner_id          284 non-null    float64
#  11  posted_time         284 non-null    object
#  12  disbursed_time      284 non-null    object
#  13  funded_time         282 non-null    object
#  14  term_in_months      284 non-null    float64
# ...

# %%
brazil.shape
# Out:
# (284, 20)

# %% [markdown]
# #checking for null values

# %%
brazil.isnull().sum()
# Out:
# id                     0
# funded_amount          0
# loan_amount            0
# activity               0
# sector                 0
# use                   41
# country_code           0
# country                0
# region                41
# currency               0
# partner_id             0
# posted_time            0
# disbursed_time         0
# funded_time            2
# term_in_months         0
# lender_count           0
# tags                  29
# borrower_genders      41
# repayment_interval     0
# date                   0
# dtype: int64

# %% [markdown]
# #checking for duplicates

# %%
duplicates=brazil.duplicated()

# %%
print(duplicates.sum())
# Out:
# 0

# %% [markdown]
# #to look at all available columns

# %%
brazil.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date'],
#       dtype='object')

# %% [markdown]
# #Dropping the null values

# %%
brazil.dropna(inplace=True)
# Out:
# <ipython-input-37-e60a99ca162c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   brazil.dropna(inplace=True)

# %%
brazil.isnull().sum()
# Out:
# id                    0
# funded_amount         0
# loan_amount           0
# activity              0
# sector                0
# use                   0
# country_code          0
# country               0
# region                0
# currency              0
# partner_id            0
# posted_time           0
# disbursed_time        0
# funded_time           0
# term_in_months        0
# lender_count          0
# tags                  0
# borrower_genders      0
# repayment_interval    0
# date                  0
# dtype: int64

# %% [markdown]
# #Country that got the most loans

# %%
country_with_most_loans=kiva['country'].value_counts().reset_index().head(10)

# %%
country_with_most_loans.columns=['country','count']

# %%
country_with_most_loans
# Out:
#        country   count
# 0  Philippines  160441
# 1        Kenya   75825
# 2  El Salvador   39875
# 3     Cambodia   34836
# 4     Pakistan   26857
# 5         Peru   22233
# 6     Colombia   21995
# 7       Uganda   20601
# 8   Tajikistan   19580
# 9      Ecuador   13521

# %% [markdown]
# #Doing a groupby of the countries to get the summation of the loan amounts

# %%
country_with_most_loans=kiva.groupby('country')['loan_amount'].sum().sort_values(ascending=False).reset_index().head(10)

# %%
country_with_most_loans
# Out:
#          country  loan_amount
# 0    Philippines   55342225.0
# 1          Kenya   34534300.0
# 2  United States   31496375.0
# 3           Peru   30867400.0
# 4       Paraguay   29629075.0
# 5    El Salvador   26603650.0
# 6       Cambodia   19872700.0
# 7        Bolivia   19843250.0
# 8         Rwanda   16646300.0
# 9         Uganda   15389350.0

# %% [markdown]
# #What sector got the most loans?

# %%
sector_with_most_loans=brazil['sector'].value_counts().reset_index().head(10)

# %%
sector_with_most_loans
# Out:
#            sector  count
# 0          Retail     61
# 1        Services     52
# 2        Clothing     43
# 3            Food     37
# 4            Arts     17
# 5    Construction      4
# 6       Wholesale      2
# 7          Health      2
# 8     Agriculture      2
# 9  Transportation      1

# %% [markdown]
# #Summation of the amount of loans per sector

# %%
sector_with_most_loans=brazil.groupby('sector')['loan_amount'].sum().sort_values(ascending=False).reset_index().head(10)

# %%
sector_with_most_loans
# Out:
#            sector  loan_amount
# 0          Retail     182075.0
# 1        Services     128575.0
# 2        Clothing      92075.0
# 3            Food      88050.0
# 4     Agriculture      32625.0
# 5    Construction      29650.0
# 6            Arts      27625.0
# 7       Wholesale       4075.0
# 8          Health       3550.0
# 9  Transportation       1200.0

# %% [markdown]
# #For top sector which activity had the highest amount of loans

# %%
brazil['sector'].value_counts()
# Out:
# sector
# Retail            61
# Services          52
# Clothing          43
# Food              37
# Arts              17
# Construction       4
# Wholesale          2
# Health             2
# Agriculture        2
# Transportation     1
# Manufacturing      1
# Name: count, dtype: int64

# %%
retail=brazil[brazil['sector']=='Retail']

# %%
retail.head(2)
# Out:
#            id  funded_amount  loan_amount         activity  sector  \
# 1685   654797         1700.0       1700.0  Cosmetics Sales  Retail
# 16333  669507         2500.0       2500.0           Retail  Retail
#
#                                            use country_code country    region  \
# 1685     To buy cream, perfume/cologne, makeup           BR  Brazil  Sorocaba
# 16333  To buy books, magazines, and newspapers           BR  Brazil  Sorocaba
#
#       currency  partner_id                posted_time  \
# 1685       BRL       337.0  2014-01-07 16:34:52+00:00
# 16333      BRL       337.0  2014-02-13 15:39:02+00:00
#
#                   disbursed_time                funded_time  term_in_months  \
# 1685   2013-12-23 08:00:00+00:00  2014-01-09 00:31:09+00:00            11.0
# 16333  2014-01-30 08:00:00+00:00  2014-02-14 09:21:13+00:00            15.0
#
#        lender_count                                         tags  \
# ...

# %%
retail.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date'],
#       dtype='object')

# %%
loan_activity=retail.groupby('activity')['loan_amount'].sum().sort_values(ascending=False).reset_index().head(10)

# %%
loan_activity
# Out:
#                   activity  loan_amount
# 0          Cosmetics Sales      46800.0
# 1                   Retail      30500.0
# 2      Home Products Sales      28925.0
# 3            General Store      13800.0
# 4  Personal Products Sales       8875.0
# 5         Electrical Goods       8100.0
# 6                  Jewelry       7325.0
# 7        Electronics Sales       6975.0
# 8        Phone Accessories       6425.0
# 9           Party Supplies       5625.0

# %%
clothing_activity=brazil[brazil['sector']=='Clothing']

# %%
clothing_activity.head(2)
# Out:
#            id  funded_amount  loan_amount        activity    sector  \
# 22719  675808         1075.0       1075.0  Clothing Sales  Clothing
# 23417  676510          650.0        650.0  Clothing Sales  Clothing
#
#                                                      use country_code country  \
# 22719         to buy closes, mannequins and accessories.           BR  Brazil
# 23417  To make the purchase of a small stock of healt...           BR  Brazil
#
#          region currency  partner_id                posted_time  \
# 22719  Sorocaba      BRL       337.0  2014-02-24 18:35:40+00:00
# 23417  Sorocaba      BRL       337.0  2014-02-25 20:06:04+00:00
#
#                   disbursed_time                funded_time  term_in_months  \
# 22719  2014-02-14 08:00:00+00:00  2014-02-27 05:43:40+00:00            14.0
# 23417  2014-02-14 08:00:00+00:00  2014-02-27 02:43:24+00:00            12.0
#
#        lender_count                          tags borrower_genders  \
# ...

# %%
clothing_activity=clothing_activity.groupby('activity')['loan_amount'].sum().sort_values(ascending=False).reset_index().head(10)

# %%
clothing_activity
# Out:
#          activity  loan_amount
# 0  Clothing Sales      80175.0
# 1        Clothing      11900.0

# %% [markdown]
# #which region had the highest loan amount?

# %%
region=brazil['region'].value_counts()

# %%
region
# Out:
# region
# Maua              74
# Diadema           63
# Santo André       40
# Sorocaba          17
# Rio de Janeiro    10
# Vila Luzita        9
# São Paulo          7
# Perdizes           1
# Botucatu           1
# Name: count, dtype: int64

# %%
loan_amount_region=brazil.groupby('region')['loan_amount'].sum().sort_values(ascending=False).reset_index().head(10)

# %%
loan_amount_region
# Out:
#            region  loan_amount
# 0         Diadema     179050.0
# 1            Maua     176075.0
# 2     Santo André     114875.0
# 3       São Paulo      32400.0
# 4        Botucatu      30000.0
# 5        Sorocaba      24275.0
# 6     Vila Luzita      20575.0
# 7  Rio de Janeiro      12150.0
# 8        Perdizes        700.0

# %%
df=loan_amount_region

# %%
fig=px.bar(df,x='region',y='loan_amount',title='Region with highest loan amount',color='loan_amount')
fig.update_layout(xaxis_tickangle=-45,yaxis_tickangle=-45,title_font_size=20,title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #What does the loan amount look like for various repayment intervals? in various sectors? in various activities?

# %%
brazil['repayment_interval'].value_counts()
# Out:
# repayment_interval
# irregular    172
# monthly       39
# bullet        11
# Name: count, dtype: int64

# %%
repayment_interval=brazil.groupby('repayment_interval')['loan_amount'].sum().sort_values(ascending=False).reset_index()

# %%
repayment_interval
# Out:
#   repayment_interval  loan_amount
# 0          irregular     471600.0
# 1            monthly     105650.0
# 2             bullet      12850.0

# %% [markdown]
# #What were the numbers between male and female recipient?

# %%
brazil.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date'],
#       dtype='object')

# %%
brazil['borrower_genders']
# Out:
# 1685                                      female
# 16301                                       male
# 16333                                     female
# 22719                                     female
# 23417                                     female
#                            ...
# 656882            female, female, female, female
# 656926            female, female, female, female
# 664680    female, female, female, female, female
# 665725            female, female, female, female
# 665789            female, female, female, female
# Name: borrower_genders, Length: 222, dtype: object

# %% [markdown]
# #Cleaning up the borrowers gender column for whitespaces

# %%
gender_list=[]
 for gender in brazil['borrower_genders'].values:
    if str(gender)!='nan':
        gender_list.extend([1st.strip() for 1st in gender.split(',')])
    else:
        gender=gender.strip()
    gender_list.append(gender)
# Out:
#   File "<ipython-input-92-50b7869f9819>", line 2
#     for gender in brazil['borrower_genders'].values:
#     ^
# IndentationError: unexpected indent

# %%
gender_list=[]
for gender in brazil['borrower_genders'].values:
    if str(gender)!='nan':
        gender_list.extend(gender.split(','))
    else:
        gender_list.append(gender)

# %%
temp_data=pd.Series(gender_list).value_counts()
gender=temp_data.to_frame().head(20).reset_index()
gender.columns=['Gender','Frequency']

# %%
gender
# Out:
#     Gender  Frequency
# 0   female        455
# 1   female        171
# 2     male        129
# 3     male         51

# %% [markdown]
# #Sector which got the highest loan amount

# %%
sector_with_most_loans=brazil.groupby('sector')['loan_amount'].sum().sort_values(ascending=False).reset_index().head(10)

# %%
sector_with_most_loans
# Out:
#            sector  loan_amount
# 0          Retail     182075.0
# 1        Services     128575.0
# 2        Clothing      92075.0
# 3            Food      88050.0
# 4     Agriculture      32625.0
# 5    Construction      29650.0
# 6            Arts      27625.0
# 7       Wholesale       4075.0
# 8          Health       3550.0
# 9  Transportation       1200.0

# %% [markdown]
# #Visualization questions

# %% [markdown]
# ##Top 10 loan activities in the data

# %%
brazil.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date'],
#       dtype='object')

# %%
top10_loan_activities=brazil.groupby('activity')['loan_amount'].count().sort_values(ascending=False).head(10).reset_index()

# %%
top10_loan_activities
# Out:
#                 activity  loan_amount
# 0         Clothing Sales           39
# 1           Beauty Salon           34
# 2        Cosmetics Sales           17
# 3                 Crafts           15
# 4                 Retail           10
# 5    Home Products Sales            9
# 6  Food Production/Sales            8
# 7               Services            8
# 8                   Food            7
# 9          General Store            5

# %%
df=top10_loan_activities

# %%
fig=px.bar(df,x='activity',y='loan_amount',title='Top 10 loan activities',color='loan_amount')
fig.update_layout(xaxis_tickangle=-45,yaxis_tickangle=-45,title_font_size=20,title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(12,8))

# %%
plt.title('Top 10 loan activities in Brazil')
sns.barplot(x='activity',y='loan_amount',data=top10_loan_activities,color='yellow')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# #most dominant field patners

# %%
themes.head()
# Out:
#    Partner ID                Field Partner Name                       sector  \
# 0         225                            Novica                      Artisan
# 1         315       Yunus Social Business (YSB)      SME Financial Inclusion
# 2         315       Yunus Social Business (YSB)      SME Financial Inclusion
# 3         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 4         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
#
#      Loan Theme ID Loan Theme Type country forkiva          region  \
# 0  a1050000000T14Q         Artisan  Brazil      No  Rio de Janeiro
# 1  a1050000002VO1d             SME  Brazil      No        Botucatu
# 2  a1050000002VO1d             SME  Brazil      No      SÍ£o Paulo
# 3  a1050000000da2V         General  Brazil      No         Diadema
# 4  a1050000000da2V         General  Brazil      No            Maua
#
#   geocode_old  ISO  ...  amount            LocationName  \
# ...

# %%
themes.tail()
# Out:
#    Partner ID                Field Partner Name                       sector  \
# 3         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 4         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 5         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 6         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 7         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
#
#      Loan Theme ID Loan Theme Type country forkiva        region geocode_old  \
# 3  a1050000000da2V         General  Brazil      No       Diadema         NaN
# 4  a1050000000da2V         General  Brazil      No          Maua         NaN
# 5  a1050000000da2V         General  Brazil      No  Santo AndrÍ©         NaN
# 6  a1050000000da2V         General  Brazil      No    SÍ£o Paulo         NaN
# 7  a1050000000da2V         General  Brazil      No   Vila Luzita         NaN
#
# ...

# %%
df=themes.head(10)

# %%
df
# Out:
#    Partner ID                Field Partner Name                       sector  \
# 0         225                            Novica                      Artisan
# 1         315       Yunus Social Business (YSB)      SME Financial Inclusion
# 2         315       Yunus Social Business (YSB)      SME Financial Inclusion
# 3         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 4         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 5         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 6         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 7         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
#
#      Loan Theme ID Loan Theme Type country forkiva          region  \
# 0  a1050000000T14Q         Artisan  Brazil      No  Rio de Janeiro
# 1  a1050000002VO1d             SME  Brazil      No        Botucatu
# 2  a1050000002VO1d             SME  Brazil      No      SÍ£o Paulo
# ...

# %%
fig=px.bar(df,x='Field Partner Name',y='region',title='most dominant field patners',color='region')
fig.update_layout(xaxis_tickangle=-45,yaxis_tickangle=-45,title_font_size=20,title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
themes['Field Partner Name'].value_counts().reset_index().head(10)
# Out:
#                  Field Partner Name  count
# 0  Banco do Povo CrÍ©dito Solidario      5
# 1       Yunus Social Business (YSB)      2
# 2                            Novica      1

# %%
themes.columns
# Out:
# Index(['Partner ID', 'Field Partner Name', 'sector', 'Loan Theme ID',
#        'Loan Theme Type', 'country', 'forkiva', 'region', 'geocode_old', 'ISO',
#        'number', 'amount', 'LocationName', 'geocode', 'names', 'geo', 'lat',
#        'lon', 'mpi_region', 'mpi_geo', 'rural_pct'],
#       dtype='object')

# %%
df
# Out:
#    Partner ID                Field Partner Name                       sector  \
# 0         225                            Novica                      Artisan
# 1         315       Yunus Social Business (YSB)      SME Financial Inclusion
# 2         315       Yunus Social Business (YSB)      SME Financial Inclusion
# 3         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 4         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 5         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 6         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
# 7         464  Banco do Povo CrÍ©dito Solidario  General Financial Inclusion
#
#      Loan Theme ID Loan Theme Type country forkiva          region  \
# 0  a1050000000T14Q         Artisan  Brazil      No  Rio de Janeiro
# 1  a1050000002VO1d             SME  Brazil      No        Botucatu
# 2  a1050000002VO1d             SME  Brazil      No      SÍ£o Paulo
# ...

# %%
fig=px.bar(df,x='Field Partner Name',y='amount',title='Partners name and their total loan amount',color='amount')
fig.update_layout(xaxis_tickangle=-45,yaxis_tickangle=-45,title_font_size=20,title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(12,8))
plt.title('Field Partners name ')
plt.xticks(rotation=75)
sns.countplot(x='Field Partner Name',data=themes,color='yellow')
plt.show()

# %%
themes.columns
# Out:
# Index(['Partner ID', 'Field Partner Name', 'sector', 'Loan Theme ID',
#        'Loan Theme Type', 'country', 'forkiva', 'region', 'geocode_old', 'ISO',
#        'number', 'amount', 'LocationName', 'geocode', 'names', 'geo', 'lat',
#        'lon', 'mpi_region', 'mpi_geo', 'rural_pct'],
#       dtype='object')

# %%
brazil.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date'],
#       dtype='object')

# %%
dominant_field_partner=themes.groupby('Partner ID')['number'].count().sort_values(ascending=False).head(10).reset_index()

# %%
dominant_field_partner
# Out:
#    Partner ID  number
# 0         464       5
# 1         315       2
# 2         225       1

# %%
plt.figure(figsize=(12,8))
plt.title('Field Partners name ')
plt.xticks(rotation=75)
sns.barplot(x='Partner ID',y='number',data=dominant_field_partner,color='yellow')
plt.show()

# %% [markdown]
# #partners names and their total loan amount

# %%
loan_themes.columns
# Out:
# Index(['Partner ID', 'Field Partner Name', 'sector', 'Loan Theme ID',
#        'Loan Theme Type', 'country', 'forkiva', 'region', 'geocode_old', 'ISO',
#        'number', 'amount', 'LocationName', 'geocode', 'names', 'geo', 'lat',
#        'lon', 'mpi_region', 'mpi_geo', 'rural_pct'],
#       dtype='object')

# %%
loan_themes_by_region.columns
# Out:
# Index(['Partner ID', 'Field Partner Name', 'sector', 'Loan Theme ID',
#        'Loan Theme Type', 'country', 'forkiva', 'region', 'geocode_old', 'ISO',
#        'number', 'amount', 'LocationName', 'geocode', 'names', 'geo', 'lat',
#        'lon', 'mpi_region', 'mpi_geo', 'rural_pct'],
#       dtype='object')

# %%
mpi.head(10)
# Out:
#               LocationName  ISO      country      region world_region    MPI  \
# 0  Badakhshan, Afghanistan  AFG  Afghanistan  Badakhshan   South Asia  0.387
# 1     Badghis, Afghanistan  AFG  Afghanistan     Badghis   South Asia  0.466
# 2     Baghlan, Afghanistan  AFG  Afghanistan     Baghlan   South Asia  0.300
# 3       Balkh, Afghanistan  AFG  Afghanistan       Balkh   South Asia  0.301
# 4      Bamyan, Afghanistan  AFG  Afghanistan      Bamyan   South Asia  0.325
# 5    Daykundi, Afghanistan  AFG  Afghanistan    Daykundi   South Asia  0.313
# 6       Farah, Afghanistan  AFG  Afghanistan       Farah   South Asia  0.319
# 7      Faryab, Afghanistan  AFG  Afghanistan      Faryab   South Asia  0.250
# 8      Ghazni, Afghanistan  AFG  Afghanistan      Ghazni   South Asia  0.245
# 9        Ghor, Afghanistan  AFG  Afghanistan        Ghor   South Asia  0.384
#
#                                geo        lat        lon
# 0  (36.7347725, 70.81199529999999)  36.734772  70.811995
# ...

# %% [markdown]
# ###partners names

# %%
partnernames_loans=themes.groupby('Field Partner Name')['amount'].sum().sort_values(ascending=False).head(10).reset_index()

# %%
partnernames_loans.head(10)
# Out:
#                  Field Partner Name  amount
# 0  Banco do Povo CrÍ©dito Solidario  669750
# 1       Yunus Social Business (YSB)   50000
# 2                            Novica    6900

# %%
fig=px.pie(partnernames_loans,values='amount',names='Field Partner Name',title='Partners name and their total loan amount')
fig.update_layout(title_font_size=20,title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Top reasons for giving a loan

# %%
brazil.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date'],
#       dtype='object')

# %%
loan_uses=brazil['use'].value_counts().head(10).reset_index()

# %%
loan_uses.columns=['use','count']

# %%
loan_uses
# Out:
#                                                  use  count
# 0                          purchase beauty products.      2
# 1                            to buy a conveyor belt.      2
# 2  to buy creams, shampoo and chemical hair produ...      2
# 3            to invest in a bulk purchase of leather      2
# 4              To buy cream, perfume/cologne, makeup      1
# 5  to buy massage gel, a thermal blanket and hair...      1
# 6                           to buy a sewing machine.      1
# 7        Celio to buy foam and fabric to make sofas.      1
# 8            to buy cosmetics, perfumes, and makeup.      1
# 9  to buy shampoo and moisturiser and to renovate...      1

# %%
plt.figure(figsize=(12,6))
plt.title('Top reasons for giving a loan')
plt.xticks(rotation=75)
sns.barplot(x='use',y='count',data=loan_uses,color='yellow')
plt.show()

# %% [markdown]
# #Most popular activity for taking loans

# %%
sns.catplot(y='activity',x=None,kind='count',data=brazil,height=8,aspect=2,order=pd.value_counts(brazil['activity']).iloc[:10].index,palette='husl')
plt.xticks(rotation=75)
plt.title('Most popular activity for taking loans')
plt.show()
# Out:
# <ipython-input-168-4d258791ebfe>:1: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# <ipython-input-168-4d258791ebfe>:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# #Top region by loan amount

# %%
brazil.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date'],
#       dtype='object')

# %%
from itertools import groupby
top_region_by_loan_amount=brazil.groupby("region")["loan_amount"].sum().sort_values(ascending=False).head(10).reset_index()

# %%
top_region_by_loan_amount
# Out:
#            region  loan_amount
# 0         Diadema     179050.0
# 1            Maua     176075.0
# 2     Santo André     114875.0
# 3       São Paulo      32400.0
# 4        Botucatu      30000.0
# 5        Sorocaba      24275.0
# 6     Vila Luzita      20575.0
# 7  Rio de Janeiro      12150.0
# 8        Perdizes        700.0

# %%
fig=px.pie(top_region_by_loan_amount,values='loan_amount',names='region',title='Top region by loan amount')
fig.update_layout(title_font_size=20,title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Correlation of the numerical values using heatmap

# %%
brazil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 1685 to 665789
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  222 non-null    int64
#  1   funded_amount       222 non-null    float64
#  2   loan_amount         222 non-null    float64
#  3   activity            222 non-null    object
#  4   sector              222 non-null    object
#  5   use                 222 non-null    object
#  6   country_code        222 non-null    object
#  7   country             222 non-null    object
#  8   region              222 non-null    object
#  9   currency            222 non-null    object
#  10  partner_id          222 non-null    float64
#  11  posted_time         222 non-null    object
#  12  disbursed_time      222 non-null    object
#  13  funded_time         222 non-null    object
#  14  term_in_months      222 non-null    float64
# ...

# %%
brazil.corr(numeric_only=True)
# Out:
#                       id  funded_amount  loan_amount  partner_id  \
# id              1.000000       0.152481     0.152481    0.576880
# funded_amount   0.152481       1.000000     1.000000   -0.002498
# loan_amount     0.152481       1.000000     1.000000   -0.002498
# partner_id      0.576880      -0.002498    -0.002498    1.000000
# term_in_months -0.242479       0.772950     0.772950   -0.392393
# lender_count    0.129929       0.975031     0.975031   -0.008424
#
#                 term_in_months  lender_count
# id                   -0.242479      0.129929
# funded_amount         0.772950      0.975031
# loan_amount           0.772950      0.975031
# partner_id           -0.392393     -0.008424
# term_in_months        1.000000      0.741493
# lender_count          0.741493      1.000000

# %%
plt.figure(figsize=(12,8))
sns.heatmap(brazil.corr(numeric_only=True),annot=True,cmap='coolwarm',linewidths=0.5)
plt.show()

# %% [markdown]
# #The distributions of loan amount

# %%
px.histogram(brazil,x='loan_amount',title='The distributions of loan amount')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
